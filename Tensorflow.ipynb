# %%
#Tensorflow is used to create machine learning models
#TENSORFLOW AND TENSORBOARD (When we want something production ready)
#Production ready -> Small and Easy -> Scaling is possible
#Numpy can do a lot of operations but it is not compatible with production systems

# Tensorflow -> Scaling became easy
#            -> Easy to create machine learning algorithm
#            -> OpenSource -> To create a community
#            -> GCP -> Provides access to tensorflow production unit 

# Working benefit of Tensorflow
# parrallel processing
# computation graph (A+B)*(B+C) -> Creating a dependency graph -> DAG(Directed Acyclic graph)-> parrallely generate a sequence which can happen parrallely 
# Tensorflow 1.0 -> Initially create a graph and then use the content
# Difficult to debug
# Git also uses a DAG structure

# %%
# Tensorflow 2.0 -> Eager execution
# will not create any DAG -> can do the basic stuff in the eager exec
# for detailed exec we need to create a dag(goes in one direction only)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
a = tf.constant(10)

# %%
b = tf.constant(20)

# %%
c = a+b

# %%
tf.executing_eagerly()
# Out:
# True

# %%
type(c.numpy())
# Out:
# numpy.int32
