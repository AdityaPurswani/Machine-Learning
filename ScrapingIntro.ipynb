# %% [markdown]
# # Scraping images from internet

# %%
import requests
import bs4

# %%
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRaYnTyri7Tf1Ptufaymv5MQhNXfL5ss0mEZQ&usqp=CAU"

res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
f = open("pandas.jpeg", "wb")
f.write(res.content)
f.close()
