# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.iterrows
# Out:
# <bound method DataFrame.iterrows of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
names = ["harsh", "Aditya", "Arjeet"]
ages = [22, 20, 20]

# %%
d = {
    "names" : names,
    "ages" : ages
}

# %%
d
# Out:
# {'ages': [22, 20, 20], 'names': ['harsh', 'Aditya', 'Arjeet']}

# %%
pd.DataFrame(d)
# Out:
#     names  ages
# 0   harsh    22
# 1  Aditya    20
# 2  Arjeet    20

# %%
import numpy as np
data = np.random.randint(0, 15, (10, 5))

# %%
data
# Out:
# array([[ 2, 13,  6,  1, 10],
#        [ 3, 10,  0,  5,  5],
#        [12,  1,  7, 11,  6],
#        [ 4,  3,  5, 14,  1],
#        [ 1,  3, 12,  8,  2],
#        [ 6,  3, 14,  5,  7],
#        [ 4,  6,  3,  4,  3],
#        [ 4, 12, 11,  1, 12],
#        [ 2,  9,  0,  8,  0],
#        [ 0,  0,  0, 13, 13]])

# %%
marks = pd.DataFrame(data , columns= {"Phy", "Chem", "Math", "Bio", "Eng"})

# %%
marks
# Out:
#    Chem  Eng  Phy  Bio  Math
# 0     2   13    6    1    10
# 1     3   10    0    5     5
# 2    12    1    7   11     6
# 3     4    3    5   14     1
# 4     1    3   12    8     2
# 5     6    3   14    5     7
# 6     4    6    3    4     3
# 7     4   12   11    1    12
# 8     2    9    0    8     0
# 9     0    0    0   13    13

# %%
marks["Bio"] = 20

# %%
marks
# Out:
#    Chem  Eng  Phy  Bio  Math
# 0     2   13    6   20    10
# 1     3   10    0   20     5
# 2    12    1    7   20     6
# 3     4    3    5   20     1
# 4     1    3   12   20     2
# 5     6    3   14   20     7
# 6     4    6    3   20     3
# 7     4   12   11   20    12
# 8     2    9    0   20     0
# 9     0    0    0   20    13

# %%
df.to_numpy()
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
marks.sort_values(["Eng"])
# Out:
#    Chem  Eng  Phy  Bio  Math
# 9     0    0    0   20    13
# 2    12    1    7   20     6
# 3     4    3    5   20     1
# 4     1    3   12   20     2
# 5     6    3   14   20     7
# 6     4    6    3   20     3
# 8     2    9    0   20     0
# 1     3   10    0   20     5
# 7     4   12   11   20    12
# 0     2   13    6   20    10

# %%
marks.sort_index(axis=1)
# Out:
#    Bio  Chem  Eng  Math  Phy
# 0   20     2   13    10    6
# 1   20     3   10     5    0
# 2   20    12    1     6    7
# 3   20     4    3     1    5
# 4   20     1    3     2   12
# 5   20     6    3     7   14
# 6   20     4    6     3    3
# 7   20     4   12    12   11
# 8   20     2    9     0    0
# 9   20     0    0    13    0

# %%
df.T
# Out:
#                  0       1       2    ...        147        148        149
# sepal_length     5.1     4.9     4.7  ...        6.5        6.2        5.9
# sepal_width      3.5       3     3.2  ...          3        3.4          3
# petal_length     1.4     1.4     1.3  ...        5.2        5.4        5.1
# petal_width      0.2     0.2     0.2  ...          2        2.3        1.8
# species       setosa  setosa  setosa  ...  virginica  virginica  virginica
#
# [5 rows x 150 columns]

# %%
marks.iloc[::2, :]
# Out:
#    Chem  Eng  Phy  Bio  Math
# 0     2   13    6   20    10
# 2    12    1    7   20     6
# 4     1    3   12   20     2
# 6     4    6    3   20     3
# 8     2    9    0   20     0

# %%
print("Yayyy")
# Out:
# Yayyy
